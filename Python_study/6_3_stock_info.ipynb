# %%
import pandas as pd 
import requests
from bs4 import BeautifulSoup



# 국내증시 상위100의 기업 이름과 url 크롤링
def get_top100(top100_url, top100_name):
    url = 'https://finance.naver.com/sise/sise_quant.nhn'
    result = requests.get(url)
    html = BeautifulSoup(result.text, 'html.parser')

    top100 = html.find_all('a', {'class':'tltle'})  
    

    for i in range(100):
        url = 'https://finance.naver.com' + top100[i]['href']    
        # print(top100[i])
        # print(top100[i]['href'])
        # print(url)        
        top100_url.append(url)
    
        company_name = top100[i].string    
        top100_name.append(company_name)

    return (top100_url, top100_name)



def get_company(top100_name):
    company_name = input('주가를 검색할 기업이름을 입력하세요: ')

    for i in range(100):
        if company_name == top100_name[i]:            
            return(i)           

    if i == 100:
        print("입력한 기업은 상위100 목록에 없습니다.")
        return(100)




def get_company_stockPage(company_url):    
    result = requests.get(company_url)
    company_stockPage = BeautifulSoup(result.content, "html.parser")
    return company_stockPage




def get_price(company_url):
    company_stockPage = get_company_stockPage(company_url)    
    no_today = company_stockPage.find("p", {"class": "no_today"})   
    # print(no_today)
    blind = no_today.find("span", {"class": "blind"})
    now_price = blind.text   
    
    return now_price



def stock_info():
    top100_url=[]
    top100_name = []

    top100_url, top100_name = get_top100(top100_url, top100_name)

    print("< 현재 네이버 금융 국내 코스피 상위100 기업 목록 >")
    print(top100_name)
    print('')

    company = int(get_company(top100_name)) 
    if company == 100:
        print("입력한 기업은 상위100 목록에 없습니다.")        
    else :        
        now_price = get_price(top100_url[company]) 
        print('%s 기업의 현재 주가는 %s 입니다' % (top100_name[company], now_price))


if __name__ == '__main__':
     stock_info()
# Out:
# < 현재 네이버 금융 국내 코스피 상위100 기업 목록 >
# ['KODEX 200선물인버스2X', '베트남개발1', 'KODEX 코스닥150선물인버스', '유니온머티리얼', '삼성 인버스 2X WTI원유 선물 ETN', '남선알미늄', 'KODEX 인버스', 'KODEX 레버리지', 'KODEX 코스닥150레버리지', '콤텍시스템', '조일알미늄', '삼성전자', '화천기계', '신한 인버스 2X 천연가스 선물 ETN', '카카오', '신한 인버스 2X WTI원유 선물 ETN(H)', 'KEC', '유니온', 'TRUE 인버스 2X 천연가스 선물 ETN(H)', '대한전선', '한미글로벌', '카카오뱅크', '세원이앤씨', '금양', 'TIGER 200선물인버스2X', 'KODEX 코스닥150', 'KODEX 200', '삼성 인버스 2X 코스닥150 선물 ETN', '두산에너빌리티', 'TRUE 인버스 2X 코스닥 150 선물 ETN', '삼성 레버리지 코스닥150 선물 ETN', '신한 인버스 2X 천연가스 선물 ETN(H)', '미래아이앤지', 'KODEX 미국나스닥100레버리지(합성 H)', 'LG디스플레이', '인바이오젠', 'IHQ', '이엔플러스', '에이프로젠', 'TIGER 차이나항셍테크', '황금에스티', '삼성엔지니어링', 'TIGER 차이나전기차SOLACTIVE', '흥아해운', '삼성중공업', '그린케미칼', '우리금융지주', '현대건설', 'TIGER 인버스', 'KR모터스', '미래에셋 인버스 2X 코스피200 선물 ETN', 'SK하이닉스', '쌍방울', '한국항공우주', 'TYM', '제이준코스메틱', '현대로템', 'QV 인버스 레버리지 WTI원유 선물 ETN(H)', '한화에어로스페이스', 'TIGER 미국필라델피아반도체나스닥', 'HMM', '제주은행', '한화솔루션', '한화생명', 'KBSTAR 단기통안채', '팬오션', '방림', '한국전력', 'NAVER', 'KODEX 2차전지산업', '코스모화학', 'STX', '인디에프', 'TRUE 인버스 2X 나스닥 100 ETN', 'KODEX WTI원유선물인버스(H)', '사조동아원', '대우건설', '벽산', '삼부토건', 'KODEX 미국달러선물인버스2X', '삼성 인버스 2X 코스피200 선물 ETN', '신한지주', '신성이엔지', 'TRUE 레버리지 코스닥 150 선물 ETN', 'KB금융', '알루코', '메리츠증권', '카카오페이', 'SH에너지화학', '씨아이테크', '금호에이치티', '기아', '한창', '무림페이퍼', 'TIGER 200', '우리종금', '삼성전자우', 'BNK금융지주', '서울식품', '쏘카']
