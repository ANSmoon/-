# %% [markdown]
# ##### Author : 문범수
# ##### date : 2024-01-28
# ##### title : 01/28 필수과제 2

# %% [markdown]
# ### 필수과제1 ( 직접 전처리 작업을 하고 난 후에 패키지를 이용해서 빈도를 확인하고 불용어 선정 )
# - 내가 정리한 불용어 리스트 공유

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('movie_rv.csv')
df
# Out:
#         Unnamed: 0        id  \
# 0                0   9976970
# 1                1   3819312
# 2                2  10265843
# 3                3   9045019
# 4                4   6483659
# ...            ...       ...
# 149995      149995   6222902
# 149996      149996   8549745
# 149997      149997   9311800
# 149998      149998   2376369
# 149999      149999   9619869
#
#                                                  document  label
# 0                                     아 더빙.. 진짜 짜증나네요 목소리      0
# 1                       흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나      1
# 2                                       너무재밓었다그래서보는것을추천한다      0
# 3                           교도소 이야기구먼 ..솔직히 재미는 없다..평점 조정      0
# 4       사이몬페그의 익살스런 연기가 돋보였던 영화!스파이더맨에서 늙어보이기만 했던 커스틴 ...      1
# ...                                                   ...    ...
# 149995                                인간이 문제지.. 소는 뭔죄인가..      0
# 149996                                      평점이 너무 낮아서...      1
# 149997                    이게 뭐요? 한국인은 거들먹거리고 필리핀 혼혈은 착하다?      0
# 149998                        청춘 영화의 최고봉.방황과 우울했던 날들의 자화상      1
# 149999                           한국 영화 최초로 수간하는 내용이 담긴 영화      0
#
# [150000 rows x 4 columns]

# %%
sample = df[0:1000]
df_1 = sample['document']
df_1
# Out:
# 0                                    아 더빙.. 진짜 짜증나네요 목소리
# 1                      흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나
# 2                                      너무재밓었다그래서보는것을추천한다
# 3                          교도소 이야기구먼 ..솔직히 재미는 없다..평점 조정
# 4      사이몬페그의 익살스런 연기가 돋보였던 영화!스파이더맨에서 늙어보이기만 했던 커스틴 ...
#                              ...
# 995                         미달이는.. 연예계를 바라보는 태도를 고쳐야 한다.
# 996                                             파괴된 관객들.
# 997                                   알콜중독자들 덕에 평점이 낮은가?
# 998    중견배우들이 만들어놓은 긴장감이 나름 긴장감있게 싸워보려했던 도술사들에 의해 헛웃음...
# 999    남자 주인공 늑대 인간으로 변하고 끝나네유. 평점 보고 안 볼까 하다가 봤는디 재밌...
# Name: document, Length: 1000, dtype: object

# %%
df_1 = df_1.str.strip()

# %%
df_1 = df_1.str.replace(pat=r'[^\w\s]', repl='', regex=True)

# %%
import nltk
from nltk import FreqDist
from nltk.tokenize import word_tokenize

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\munbe\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
words = []
for sentence in df1:
    words.extend(word_tokenize(sentence))

# %%
freq_dist = FreqDist(words)

# %%
# 가장 빈도가 높은 단어 출력
print(freq_dist.most_common())
# Out:
# [('.', 413), ('..', 191), ('!', 182), (',', 177), ('...', 164), ('영화', 127), ('?', 115), ('정말', 57), (';', 55), ('진짜', 54), ('너무', 46), ('....', 44), ('이', 36), ('그냥', 26), ('다', 26), ('왜', 25), ('더', 24), ('보고', 23), ('없다', 19), ('없는', 19), ('본', 18), ('영화가', 18), ('완전', 18), ('그', 18), ('잘', 17), ('ㅋㅋ', 17), ('최고의', 17), ('좀', 16), ('아', 15), ('연기', 15), ('수', 15), ('또', 15), ('하는', 15), ('솔직히', 14), ('있는', 14), ('이건', 14), ('ㅠㅠ', 14), ('영화는', 13), ('내가', 13), ('하고', 13), ('이런', 13), ('역시', 13), ('아깝다', 12), ('참', 12), ('최고', 12), ("'", 12), ('난', 12), ('(', 12), (')', 12), ('영화를', 12), ('이거', 12), ('스토리도', 11), ('무슨', 11), ('작품', 11), ('그리고', 11), ('하나', 11), ('평점', 10), ('넘', 10), ('다시', 10), ('없고', 10), ('ㅋㅋㅋ', 10), ('.....', 10), ('영화다', 10), ('재밌게', 10), ('시간이', 10), ('내', 10), ('좋은', 10), ('평점이', 9), ('듯', 9), ('보는', 9), ('근데', 9), (':', 9), ('쓰레기', 9), ('이게', 9), ('많이', 9), ('어떻게', 9), ("''", 9), ('ㅎㅎ', 9), ('봤는데', 9), ('재미도', 9), ('재미', 8), ('ㅡㅡ', 8), ('%', 8), ('하나도', 8), ('재미있게', 8), ('전혀', 8), ('드라마', 8), ('나름', 7), ('건', 7), ('재미없다', 7), ('아닌', 7), ('재밌는데', 7), ('이렇게', 7), ('내용도', 7), ('^^', 7), ('싶다', 7), ('제일', 7), ('줄', 7), ('한', 7), ('아주', 7), ('요즘', 7), ('와', 7), ('개', 7), ('스토리', 7), ('보면', 6), ('가장', 6), ('않는', 6), ('있고', 6), ('별로', 6), ('좋았어요', 6), ('모르겠다', 6), ('10점', 6), ('ㅋ', 6), ('느낌', 6), ('생각이', 6), ('보는내내', 6), ('그런', 6), ('그래도', 6), ('재밌음', 6), ('진심', 6), ('봤습니다', 6), ('봐도', 6), ('여운이', 6), ('봤던', 6), ('말이', 6), ('굿', 6), ('액션', 6), ('내내', 6), ('연기도', 6), ('싶은', 6), ('중', 6), ('것', 6), ('영화의', 6), ('끝까지', 6), ('연기가', 5), ('별', 5), ('꽤', 5), ('사람들', 5), ('갈수록', 5), ('절대', 5), ('보면서', 5), ('지루하고', 5), ('같은', 5), ('그래서', 5), ('한번', 5), ('아직도', 5), ('대한', 5), ('조금', 5), ('딱', 5), ('있을까', 5), ('ㅜㅜ', 5), ('내용은', 5), ('안', 5), ('실망', 5), ('감독이', 5), ('뭘', 5), ('연기를', 5), ('볼', 5), ('아니', 5), ('사랑에', 5), ('그만', 5), ('-', 5), ('남는', 5), ('연기는', 5), ('아름다운', 5), ('감동적인', 5), ('지금', 5), ('할', 5), ('결국', 5), ('마지막에', 5), ('만드는', 5), ('아니라', 5), ('연출', 5), ('재미는', 4), ('너무나도', 4), ('막', 4), ('위한', 4), ('꼭', 4), ('대체', 4), ('나도', 4), ('영화에', 4), ('그저', 4), ('나와서', 4), ('사람들이', 4), ('대해', 4), ('일본영화', 4), ('내용', 4), ('자체는', 4), ('뭐냐', 4), ('재밌고', 4), ('시청률', 4), ('봤다', 4), ('소재는', 4), ('특유의', 4), ('현실감', 4), ('따뜻한', 4), ('......', 4), ('인생', 4), ('충분히', 4), ('오랜만에', 4), ('하지만', 4), ('않고', 4), ('주인공이', 4), ('감독의', 4), ('최악', 4), ('것도', 4), ('또한', 4), ('다른', 4), ('사람들의', 4), ('그때', 4), ('장면', 4), ('없었다', 4), ('기대', 4), ('감독', 4), ('배우들의', 4), ('명작', 4), ('재밌다', 4), ('주인공', 4), ('+', 4), ('모든', 4), ('좋고', 4), ('못한', 4), ('있지만', 4), ('아쉬운', 4), ('아까운', 4), ('인간의', 4), ('당시', 4), ('같다', 4), ('뭔가', 4), ('모두', 4), ('안되는', 4), ('기분', 4), ('쓰레기영화', 4), ('*', 4), ('초등학교', 3), ('아까움', 3), ('좋다', 3), ('보다', 3), ('극장에서', 3), ('있는데', 3), ('지루하다', 3), ('캐스팅', 3), ('1', 3), ('없음', 3), ('방법이', 3), ('>', 3), ('멋진', 3), ('합니다', 3), ('주고', 3), ('싶은데', 3), ('웃음', 3), ('했음', 3), ('사람의', 3), ('잠시', 3), ('감동', 3), ('OO', 3), ('혼자', 3), ('완전히', 3), ('무거운', 3), ('든다', 3), ('그대로', 3), ('많은', 3), ('우리나라', 3), ('바로', 3), ('에피소드', 3), ('봤어요', 3), ('차', 3), ('졸작', 3), ('전개', 3), ('결말', 3), ('아햏햏', 3), ('진정', 3), ('내일이', 3), ('설정이', 3), ('재미없음', 3), ('생각보다', 3), ('되는', 3), ('내용이', 3), ('너무나', 3), ('이야기', 3), ('도대체', 3), ('이렇게까지', 3), ('전부', 3), ('어느', 3), ('마세요', 3), ('만들어', 3), ('배우들은', 3), ('영화입니다', 3), ('같음', 3), ('``', 3), ('저예산', 3), ('꽤나', 3), ('시종일관', 3), ('상당히', 3), ('별점', 3), ('밖에', 3), ('사람', 3), ('보지', 3), ('-_-', 3), ('아니다', 3), ('좋았지만', 3), ('전에', 3), ('아니면', 3), ('2', 3), ('시리즈', 3), ('일본', 3), ('봐라', 3), ('평점은', 3), ('어떤', 3), ('지루한', 3), ('보니까', 3), ('재밌네요', 3), ('보고싶은', 3), ('색다른', 3), ('.......', 3), ('연기력', 3), ('더빙이', 3), ('말', 3), ('기억이', 3), ('웃겨', 3), ('가슴이', 3), ('재미없다고', 3), ('겁나', 3), ('느낌이', 3), ('이런영화가', 3), ('남을', 3), ('슬픔', 3), ('나오는', 3), ('느낀다', 3), ('감동을', 3), ('있음', 3), ('영상이', 3), ('둘', 3), ('기억에', 3), ('0점은', 3), ('최악의', 3), ('떠나', 3), ('그러나', 3), ('최고다', 3), ('뭔지', 3), ('감정을', 3), ('인간이', 3), ('재미가', 3), (' ...
