# %%
import missingno as msn
import pandas as pd
import numpy as np
import matplotlib.pyplot as pl

# %%
df=pd.read_csv('bike_sharing_daily.csv')

# %%
df.isna().sum()
# Out:
# instant        0
# dteday         0
# season         0
# yr             0
# mnth           0
# holiday        0
# weekday        0
# workingday     0
# weathersit     0
# temp          17
# atemp         24
# hum           25
# windspeed     13
# casual        11
# registered    11
# cnt            0
# dtype: int64

# %%
msn.matrix(df)
pl.show()

# %%
df
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  2011-01-01       1   0     1        0        6           0
# 1          2  2011-01-02       1   0     1        0        0           0
# 2          3  2011-01-03       1   0     1        0        1           1
# 3          4  2011-01-04       1   0     1        0        2           1
# 4          5  2011-01-05       1   0     1        0        3           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 726      727  2012-12-27       1   1    12        0        4           1
# 727      728  2012-12-28       1   1    12        0        5           1
# 728      729  2012-12-29       1   1    12        0        6           0
# 729      730  2012-12-30       1   1    12        0        0           0
# 730      731  2012-12-31       1   1    12        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# ...

# %%
df.dropna()
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  2011-01-01       1   0     1        0        6           0
# 1          2  2011-01-02       1   0     1        0        0           0
# 3          4  2011-01-04       1   0     1        0        2           1
# 4          5  2011-01-05       1   0     1        0        3           1
# 5          6  2011-01-06       1   0     1        0        4           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 723      724  2012-12-24       1   1    12        0        1           1
# 724      725  2012-12-25       1   1    12        1        2           0
# 726      727  2012-12-27       1   1    12        0        4           1
# 728      729  2012-12-29       1   1    12        0        6           0
# 730      731  2012-12-31       1   1    12        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# ...

# %%
at_mean=bike['atemp'].mean()
at_mean
# Out:
# 0.21927678947368423

# %%
df['atemp'].fillna(ws_mean).to_frame()
# Out:
#         atemp
# 0    0.363625
# 1    0.353739
# 2    0.191136
# 3    0.212122
# 4    0.229270
# ..        ...
# 726  0.226642
# 727  0.191136
# 728  0.242400
# 729  0.231700
# 730  0.223487
#
# [731 rows x 1 columns]

# %%
# atemp 0으로 대체?
df['atemp'].fillna(0).to_frame()
# Out:
#         atemp
# 0    0.363625
# 1    0.353739
# 2    0.000000
# 3    0.212122
# 4    0.229270
# ..        ...
# 726  0.226642
# 727  0.000000
# 728  0.242400
# 729  0.231700
# 730  0.223487
#
# [731 rows x 1 columns]

# %% [markdown]
# ### ffill

# %%
df['atemp'].fillna(method='ffill').to_frame()
# Out:
#         atemp
# 0    0.363625
# 1    0.353739
# 2    0.353739
# 3    0.212122
# 4    0.229270
# ..        ...
# 726  0.226642
# 727  0.226642
# 728  0.242400
# 729  0.231700
# 730  0.223487
#
# [731 rows x 1 columns]

# %%
df.atemp.to_frame()
# Out:
#         atemp
# 0    0.363625
# 1    0.353739
# 2         NaN
# 3    0.212122
# 4    0.229270
# ..        ...
# 726  0.226642
# 727       NaN
# 728  0.242400
# 729  0.231700
# 730  0.223487
#
# [731 rows x 1 columns]

# %%
df['atemp'].fillna(method='bfill').to_frame()
# Out:
#         atemp
# 0    0.363625
# 1    0.353739
# 2    0.212122
# 3    0.212122
# 4    0.229270
# ..        ...
# 726  0.226642
# 727  0.242400
# 728  0.242400
# 729  0.231700
# 730  0.223487
#
# [731 rows x 1 columns]

# %% [markdown]
# ### interpolate

# %%
df['atemp'].interpolate().to_frame()
# Out:
#         atemp
# 0    0.363625
# 1    0.353739
# 2    0.282931
# 3    0.212122
# 4    0.229270
# ..        ...
# 726  0.226642
# 727  0.234521
# 728  0.242400
# 729  0.231700
# 730  0.223487
#
# [731 rows x 1 columns]

# %%
bike=df.iloc[0:20, 10:15]
bike
# Out:
#        atemp       hum  windspeed  casual  registered
# 0   0.363625  0.805833   0.160446   331.0       654.0
# 1   0.353739  0.696087   0.248539   131.0       670.0
# 2        NaN  0.437273   0.248309   120.0      1229.0
# 3   0.212122  0.590435   0.160296   108.0      1454.0
# 4   0.229270  0.436957   0.186900    82.0      1518.0
# 5   0.233209  0.518261   0.089565    88.0      1518.0
# 6   0.208839  0.498696   0.168726   148.0      1362.0
# 7   0.162254  0.535833   0.266804    68.0       891.0
# 8   0.116175  0.434167   0.361950    54.0       768.0
# 9   0.150888  0.482917   0.223267    41.0      1280.0
# 10  0.191464  0.686364   0.122132    43.0      1220.0
# 11  0.160473       NaN   0.304627    25.0      1137.0
# 12  0.150883  0.470417   0.301000    38.0      1368.0
# 13  0.188413  0.537826   0.126548    54.0      1367.0
# 14  0.248112  0.498750   0.157963   222.0         NaN
# 15  0.234217  0.483750   0.188433   251.0       953.0
# ...

# %%
bike['atemp'].fillna(method='bfill').to_frame()
# Out:
#        atemp
# 0   0.363625
# 1   0.353739
# 2   0.212122
# 3   0.212122
# 4   0.229270
# 5   0.233209
# 6   0.208839
# 7   0.162254
# 8   0.116175
# 9   0.150888
# 10  0.191464
# 11  0.160473
# 12  0.150883
# 13  0.188413
# 14  0.248112
# 15  0.234217
# 16  0.176771
# 17  0.232333
# 18  0.298422
# 19  0.255050

# %%
bike['atemp'].plot() #-> 떨어지므로 결측값이 있음.
# Out:
# <AxesSubplot:>

# %%
bike['atemp'].fillna(0).plot()
# Out:
# <AxesSubplot:>

# %%
bike['atemp'].fillna(at_mean).plot()
# Out:
# <AxesSubplot:>

# %%
at_mean
# Out:
# 0.21927678947368423

# %% [markdown]
# ### 선형 보간법

# %%
bike['atemp'].interpolate(method='linear').plot()
# Out:
# <AxesSubplot:>

# %%
# 항 차수 높임
bike['atemp'].interpolate(method='slinear').plot()
# Out:
# <AxesSubplot:>

# %%
bike['atemp'].interpolate(method='cubic').plot()
# Out:
# <AxesSubplot:>

# %%
# 2차원 이상(spline)
bike['atemp'].interpolate(method='spline', order=2).plot()
# Out:
# <AxesSubplot:>

# %%
df
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  2011-01-01       1   0     1        0        6           0
# 1          2  2011-01-02       1   0     1        0        0           0
# 2          3  2011-01-03       1   0     1        0        1           1
# 3          4  2011-01-04       1   0     1        0        2           1
# 4          5  2011-01-05       1   0     1        0        3           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 726      727  2012-12-27       1   1    12        0        4           1
# 727      728  2012-12-28       1   1    12        0        5           1
# 728      729  2012-12-29       1   1    12        0        6           0
# 729      730  2012-12-30       1   1    12        0        0           0
# 730      731  2012-12-31       1   1    12        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# ...

# %%
df['dteday']=pd.to_datetime(df['dteday'])
df2=df.set_index('dteday')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    datetime64[ns]
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        714 non-null    float64
#  10  atemp       707 non-null    float64
#  11  hum         706 non-null    float64
#  12  windspeed   718 non-null    float64
#  13  casual      720 non-null    float64
#  14  registered  720 non-null    float64
#  15  cnt         731 non-null    int64
# dtypes: datetime64[ns](1), float64(6), int64(9)
# memory usage: 91.5 KB

# %%
df2.iloc[0:20, 0:15]['atemp'].interpolate(method='time').to_frame()
# Out:
#                atemp
# dteday
# 2011-01-01  0.363625
# 2011-01-02  0.353739
# 2011-01-03  0.282931
# 2011-01-04  0.212122
# 2011-01-05  0.229270
# 2011-01-06  0.233209
# 2011-01-07  0.208839
# 2011-01-08  0.162254
# 2011-01-09  0.116175
# 2011-01-10  0.150888
# 2011-01-11  0.191464
# 2011-01-12  0.160473
# 2011-01-13  0.150883
# 2011-01-14  0.188413
# 2011-01-15  0.248112
# 2011-01-16  0.234217
# 2011-01-17  0.176771
# 2011-01-18  0.232333
# 2011-01-19  0.298422
# 2011-01-20  0.255050
